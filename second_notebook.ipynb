# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

df2 = pd.read_excel("./data/cars_mpg.xlsx")

# %%
df2.acceleration.plot(title='acceleration');

# %%
df2.acceleration.hist();

# %%
df.mpg.plot(title='mpg')
